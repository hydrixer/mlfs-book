# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#1EB182;"> **Air Quality** </span><span style="font-width:bold; font-size: 3rem; color:#333;">- Part 04: Batch Inference</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Download model and batch inference data
# 2. Make predictions, generate PNG for forecast
# 3. Store predictions in a monitoring feature group adn generate PNG for hindcast

# %% [markdown]
# ## <span style='color:#ff5f27'> 📝 Imports

# %%
import datetime
import pandas as pd
from xgboost import XGBRegressor
import hopsworks
import json
from functions import util
import os

# %%
today = datetime.datetime.now() - datetime.timedelta(0)
tomorrow = today + datetime.timedelta(days = 1)
today
# Out:
# datetime.datetime(2024, 11, 19, 0, 46, 57, 238039)

# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connect to Hopsworks Feature Store </span>

# %%
os.environ["HOPSWORKS_API_KEY"] = "bH1DySXH2xPWRdHN.F7jezZJCnUh9rgQGdp4le5lCCAQuSaVWGtXzCNFSfGK6f8ReerVQfxxdJehhO2OU" ###
project = hopsworks.login()
fs = project.get_feature_store() 

secrets = util.secrets_api(project.name)
location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value
location = json.loads(location_str)
country=location['country']
city=location['city']
street=location['street']
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1169557
# 2024-11-19 00:46:58,739 WARNING: using legacy validation callback
# Connected. Call `.close()` to terminate connection gracefully.
# Connected. Call `.close()` to terminate connection gracefully.

# %% [markdown]
# ## <span style="color:#ff5f27;"> ⚙️ Feature View Retrieval</span>

# %%
feature_view = fs.get_feature_view(
    name='air_quality_fv',
    version=1,
)

# %% [markdown]
# ## <span style="color:#ff5f27;">🪝 Download the model from Model Registry</span>

# %%
mr = project.get_model_registry()

retrieved_model = mr.get_model(
    name="air_quality_xgboost_model",
    version=2,
)

# Download the saved model artifacts to a local directory
saved_model_dir = retrieved_model.download()
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
# Downloading model artifact (1 dirs, 5 files)... DONE

# %%
# Loading the XGBoost regressor model and label encoder from the saved model directory
# retrieved_xgboost_model = joblib.load(saved_model_dir + "/xgboost_regressor.pkl")
retrieved_xgboost_model = XGBRegressor()

retrieved_xgboost_model.load_model(saved_model_dir + "/model.json")

# Displaying the retrieved XGBoost regressor model
retrieved_xgboost_model
# Out:
# XGBRegressor(base_score='8.494896E1', booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None,
#              feature_types=['float', 'float', 'float', 'float'], gamma=None,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## <span style="color:#ff5f27;">✨ Get Weather Forecast Features with Feature View   </span>

# %%
weather_fg = fs.get_feature_group(
    name='weather',
    version=1,
)
batch_data = weather_fg.filter(weather_fg.date >=today).read()
batch_data
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.62s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2024-11-27 00:00:00+00:00                 5.35                0.0
# 1 2024-11-23 00:00:00+00:00                11.85                0.0
# 2 2024-11-20 00:00:00+00:00                12.30                0.0
# 3 2024-11-26 00:00:00+00:00                 7.50                0.0
# 4 2024-11-24 00:00:00+00:00                13.85                0.0
# 5 2024-11-21 00:00:00+00:00                12.60                0.0
# 6 2024-11-22 00:00:00+00:00                12.85                0.0
# 7 2024-11-25 00:00:00+00:00                14.95                0.2
#
#    wind_speed_10m_max  wind_direction_10m_dominant      city
# 0            5.588703                   255.068527  shanghai
# 1            6.618519                    44.999897  shanghai
# 2            6.151683                   339.443878  shanghai
# 3           12.413477                   299.538696  shanghai
# 4            5.447788                    97.594551  shanghai
# 5            5.860375                   349.380402  shanghai
# 6            8.825508                    11.768270  shanghai
# 7           12.979984                   303.690094  shanghai

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Making the predictions</span>

# %%
batch_data['predicted_pm25'] = retrieved_xgboost_model.predict(
    batch_data[['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant']])
batch_data
# Out:
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2024-11-27 00:00:00+00:00                 5.35                0.0
# 1 2024-11-23 00:00:00+00:00                11.85                0.0
# 2 2024-11-20 00:00:00+00:00                12.30                0.0
# 3 2024-11-26 00:00:00+00:00                 7.50                0.0
# 4 2024-11-24 00:00:00+00:00                13.85                0.0
# 5 2024-11-21 00:00:00+00:00                12.60                0.0
# 6 2024-11-22 00:00:00+00:00                12.85                0.0
# 7 2024-11-25 00:00:00+00:00                14.95                0.2
#
#    wind_speed_10m_max  wind_direction_10m_dominant      city  predicted_pm25
# 0            5.588703                   255.068527  shanghai      175.006073
# 1            6.618519                    44.999897  shanghai      169.685745
# 2            6.151683                   339.443878  shanghai      109.961441
# 3           12.413477                   299.538696  shanghai      115.286392
# 4            5.447788                    97.594551  shanghai      109.614105
# 5            5.860375                   349.380402  shanghai       79.925140
# 6            8.825508                    11.768270  shanghai      143.765457
# 7           12.979984                   303.690094  shanghai      100.571823

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         8 non-null      datetime64[us, UTC]
#  1   temperature_2m_mean          8 non-null      float32
#  2   precipitation_sum            8 non-null      float32
#  3   wind_speed_10m_max           8 non-null      float32
#  4   wind_direction_10m_dominant  8 non-null      float32
#  5   city                         8 non-null      object
#  6   predicted_pm25               8 non-null      float32
# dtypes: datetime64[us, UTC](1), float32(5), object(1)
# memory usage: 420.0+ bytes

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Saving the predictions (for monitoring) to a Feature Group</span>

# %%
batch_data['street'] = street
batch_data['city'] = city
batch_data['country'] = country
# Fill in the number of days before the date on which you made the forecast (base_date)
batch_data['days_before_forecast_day'] = range(1, len(batch_data)+1)
batch_data = batch_data.sort_values(by=['date'])
batch_data
# Out:
#                        date  temperature_2m_mean  precipitation_sum  \
# 2 2024-11-20 00:00:00+00:00                12.30                0.0
# 5 2024-11-21 00:00:00+00:00                12.60                0.0
# 6 2024-11-22 00:00:00+00:00                12.85                0.0
# 1 2024-11-23 00:00:00+00:00                11.85                0.0
# 4 2024-11-24 00:00:00+00:00                13.85                0.0
# 7 2024-11-25 00:00:00+00:00                14.95                0.2
# 3 2024-11-26 00:00:00+00:00                 7.50                0.0
# 0 2024-11-27 00:00:00+00:00                 5.35                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant      city  predicted_pm25  \
# 2            6.151683                   339.443878  shanghai      109.961441
# 5            5.860375                   349.380402  shanghai       79.925140
# 6            8.825508                    11.768270  shanghai      143.765457
# 1            6.618519                    44.999897  shanghai      169.685745
# 4            5.447788                    97.594551  shanghai      109.614105
# 7           12.979984                   303.690094  shanghai      100.571823
# 3           12.413477                   299.538696  shanghai      115.286392
# 0            5.588703                   255.068527  shanghai      175.006073
#
#               street country  days_before_forecast_day
# 2  songjiang library   china                         3
# 5  songjiang library   china                         6
# 6  songjiang library   china                         7
# 1  songjiang library   china                         2
# 4  songjiang library   china                         5
# 7  songjiang library   china                         8
# 3  songjiang library   china                         4
# 0  songjiang library   china                         1

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 2 to 0
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         8 non-null      datetime64[us, UTC]
#  1   temperature_2m_mean          8 non-null      float32
#  2   precipitation_sum            8 non-null      float32
#  3   wind_speed_10m_max           8 non-null      float32
#  4   wind_direction_10m_dominant  8 non-null      float32
#  5   city                         8 non-null      object
#  6   predicted_pm25               8 non-null      float32
#  7   street                       8 non-null      object
#  8   country                      8 non-null      object
#  9   days_before_forecast_day     8 non-null      int64
# dtypes: datetime64[us, UTC](1), float32(5), int64(1), object(3)
# memory usage: 544.0+ bytes

# %% [markdown]
# ### Create Forecast Graph
# Draw a graph of the predictions with dates as a PNG and save it to the github repo
# Show it on github pages

# %%
file_path = "../../docs/air-quality/assets/img/pm25_forecast.png"
plt = util.plot_air_quality_forecast(city, street, batch_data, file_path)
plt.show()
# Out:
# 2024-11-19 00:47:07,729 WARNING: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.

# %%
# Get or create feature group
monitor_fg = fs.get_or_create_feature_group(
    name='aq_predictions',
    description='Air Quality prediction monitoring',
    version=1,
    primary_key=['city','street','date','days_before_forecast_day'],
    event_time="date"
)

# %%
monitor_fg.insert(batch_data, write_options={"wait_for_job": True})
# Out:
# Uploading Dataframe: 0.00% |          | Rows 0/8 | Elapsed Time: 00:00 | Remaining Time: ?
# ---------------------------------------------------------------------------
# KafkaException                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 monitor_fg.insert(batch_data, write_options={"wait_for_job": True})
#
# File /var/data/python/lib/python3.12/site-packages/hsfs/feature_group.py:2528, in FeatureGroup.insert(self, features, overwrite, operation, storage, write_options, validation_options, save_code, wait)
#    2525 if "wait_for_job" not in write_options:
#    2526     write_options["wait_for_job"] = wait
# -> 2528 job, ge_report = self._feature_group_engine.insert(
#    2529     self,
#    2530     feature_dataframe=feature_dataframe,
#    2531     overwrite=overwrite,
#    2532     operation=operation,
#    2533     storage=storage.lower() if storage is not None else None,
#    2534     write_options=write_options,
#    2535     validation_options={"save_report": True, **validation_options},
#    2536 )
#    2537 if save_code and (
#    2538     ge_report is None or ge_report.ingestion_result == "INGESTED"
#    2539 ):
#    2540     self._code_engine.save_code(self)
#
# File /var/data/python/lib/python3.12/site-packages/hsfs/core/feature_group_engine.py:132, in FeatureGroupEngine.insert(self, feature_group, feature_dataframe, overwrite, operation, storage, write_options, validation_options)
#     128 if overwrite:
#     129     self._feature_group_api.delete_content(feature_group)
#     131 return (
# --> 132     engine.get_instance().save_dataframe(
#     133         feature_group,
#     134         feature_dataframe,
#     135         "bulk_insert" if overwrite else operation,
#     136         feature_group.online_enabled,
#     137         storage,
#     138         offline_write_options,
#     139         online_write_options,
#     140     ),
#     141     ge_report,
#     142 )
#
# File /var/data/python/lib/python3.12/site-packages/hsfs/engine/python.py:593, in Engine.save_dataframe(self, feature_group, dataframe, operation, online_enabled, storage, offline_write_options, online_write_options, validation_id)
#     578 def save_dataframe(
#     579     self,
#     580     feature_group: FeatureGroup,
#    (...)
#     587     validation_id: int = None,
#     588 ):
#     589     if (
#     590         isinstance(feature_group, ExternalFeatureGroup)
#     591         and feature_group.online_enabled
#     592     ) or feature_group.stream:
# --> 593         return self._write_dataframe_kafka(
#     594             feature_group, dataframe, offline_write_options
#     595         )
#     596     else:
#     597         # for backwards compatibility
#     598         return self.legacy_save_dataframe(
#     599             feature_group,
#     600             dataframe,
#    (...)
#     606             validation_id,
#     607         )
#
# File /var/data/python/lib/python3.12/site-packages/hsfs/engine/python.py:1019, in Engine._write_dataframe_kafka(self, feature_group, dataframe, offline_write_options)
#    1010     progress_bar = tqdm(
#    1011         total=dataframe.shape[0],
#    1012         bar_format="{desc}: {percentage:.2f}% |{bar}| Rows {n_fmt}/{total_fmt} | "
#    (...)
#    1015         mininterval=1,
#    1016     )
#    1018     # set initial_check_point to the current offset
# -> 1019     initial_check_point = self._kafka_get_offsets(
#    1020         feature_group, offline_write_options, True
#    1021     )
#    1023 def acked(err, msg):
#    1024     if err is not None:
#
# File /var/data/python/lib/python3.12/site-packages/hsfs/engine/python.py:1134, in Engine._kafka_get_offsets(self, feature_group, offline_write_options, high)
#    1130 for partition_metadata in topics.get(topic_name).partitions.values():
#    1131     partition = TopicPartition(
#    1132         topic=topic_name, partition=partition_metadata.id
#    1133     )
# -> 1134     offsets += f",{partition_metadata.id}:{consumer.get_watermark_offsets(partition)[tuple_value]}"
#    1135 consumer.close()
#    1137 return f" -initialCheckPointString {topic_name + offsets}"
#
# KafkaException: KafkaError{code=_UNKNOWN_PARTITION,val=-190,str="Failed to get watermark offsets: Local: Unknown partition"}

# %%
# We will create a hindcast chart for  only the forecasts made 1 day beforehand
monitoring_df = monitor_fg.filter(monitor_fg.days_before_forecast_day == 1).read()
monitoring_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (3.11s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2024-11-27 00:00:00+00:00                 5.35                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant      city  predicted_pm25  \
# 0            5.588703                   255.068527  shanghai      175.006073
#
#               street country  days_before_forecast_day
# 0  songjiang library   china                         1

# %%
air_quality_fg = fs.get_feature_group(
    name='air_quality',
    version=1,
)
air_quality_df = air_quality_fg.read()
air_quality_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.32s)
#                           date   pm25 country      city             street  \
# 0    2021-10-22 00:00:00+00:00  154.0   china  shanghai  songjiang library
# 1    2024-04-15 00:00:00+00:00  130.0   china  shanghai  songjiang library
# 2    2021-05-13 00:00:00+00:00   69.0   china  shanghai  songjiang library
# 3    2019-11-29 00:00:00+00:00   64.0   china  shanghai  songjiang library
# 4    2021-08-27 00:00:00+00:00   82.0   china  shanghai  songjiang library
# ...                        ...    ...     ...       ...                ...
# 2218 2023-04-16 00:00:00+00:00  113.0   china  shanghai  songjiang library
# 2219 2024-07-09 00:00:00+00:00   50.0   china  shanghai  songjiang library
# 2220 2022-10-09 00:00:00+00:00   82.0   china  shanghai  songjiang library
# 2221 2023-07-15 00:00:00+00:00   79.0   china  shanghai  songjiang library
# 2222 2023-07-10 00:00:00+00:00   67.0   china  shanghai  songjiang library
#
#                                     url  pm25in3day
# 0     https://api.waqi.info/feed/@10214   91.000000
# 1     https://api.waqi.info/feed/@10214   84.666667
# 2     https://api.waqi.info/feed/@10214   90.000000
# 3     https://api.waqi.info/feed/@10214   63.333333
# 4     https://api.waqi.info/feed/@10214   87.666667
# ...                                 ...         ...
# 2218  https://api.waqi.info/feed/@10214  118.000000
# 2219  https://api.waqi.info/feed/@10214   70.666667
# 2220  https://api.waqi.info/feed/@10214   59.333333
# 2221  https://api.waqi.info/feed/@10214   81.000000
# 2222  https://api.waqi.info/feed/@10214   81.666667
#
# [2223 rows x 7 columns]

# %%
outcome_df = air_quality_df[['date', 'pm25']]
preds_df =  monitoring_df[['date', 'predicted_pm25']]

hindcast_df = pd.merge(preds_df, outcome_df, on="date")
hindcast_df = hindcast_df.sort_values(by=['date'])

# If there are no outcomes for predictions yet, generate some predictions/outcomes from existing data
if len(hindcast_df) == 0:
    hindcast_df = util.backfill_predictions_for_monitoring(weather_fg, air_quality_df, monitor_fg, retrieved_xgboost_model)
hindcast_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.86s)
# Uploading Dataframe: 0.00% |          | Rows 0/1 | Elapsed Time: 00:00 | Remaining Time: ?
# ---------------------------------------------------------------------------
# KafkaException                            Traceback (most recent call last)
# Cell In[29], line 9
#       7 # If there are no outcomes for predictions yet, generate some predictions/outcomes from existing data
#       8 if len(hindcast_df) == 0:
# ----> 9     hindcast_df = util.backfill_predictions_for_monitoring(weather_fg, air_quality_df, monitor_fg, retrieved_xgboost_model)
#      10 hindcast_df
#
# File ~/桌面/ID2223-LAB1-RKW/mlfs-book/notebooks/ch03/functions/util.py:307, in backfill_predictions_for_monitoring(weather_fg, air_quality_df, monitor_fg, model)
#     305 hindcast_df = df
#     306 df = df.drop('pm25', axis=1)
# --> 307 monitor_fg.insert(df, write_options={"wait_for_job": True})
#     308 return hindcast_df
#
# File /var/data/python/lib/python3.12/site-packages/hsfs/feature_group.py:2528, in FeatureGroup.insert(self, features, overwrite, operation, storage, write_options, validation_options, save_code, wait)
#    2525 if "wait_for_job" not in write_options:
#    2526     write_options["wait_for_job"] = wait
# -> 2528 job, ge_report = self._feature_group_engine.insert(
#    2529     self,
#    2530     feature_dataframe=feature_dataframe,
#    2531     overwrite=overwrite,
#    2532     operation=operation,
#    2533     storage=storage.lower() if storage is not None else None,
#    2534     write_options=write_options,
#    2535     validation_options={"save_report": True, **validation_options},
#    2536 )
#    2537 if save_code and (
#    2538     ge_report is None or ge_report.ingestion_result == "INGESTED"
#    2539 ):
#    2540     self._code_engine.save_code(self)
#
# File /var/data/python/lib/python3.12/site-packages/hsfs/core/feature_group_engine.py:132, in FeatureGroupEngine.insert(self, feature_group, feature_dataframe, overwrite, operation, storage, write_options, validation_options)
#     128 if overwrite:
#     129     self._feature_group_api.delete_content(feature_group)
#     131 return (
# --> 132     engine.get_instance().save_dataframe(
#     133         feature_group,
#     134         feature_dataframe,
#     135         "bulk_insert" if overwrite else operation,
#     136         feature_group.online_enabled,
#     137         storage,
#     138         offline_write_options,
#     139         online_write_options,
#     140     ),
#     141     ge_report,
#     142 )
#
# File /var/data/python/lib/python3.12/site-packages/hsfs/engine/python.py:593, in Engine.save_dataframe(self, feature_group, dataframe, operation, online_enabled, storage, offline_write_options, online_write_options, validation_id)
#     578 def save_dataframe(
#     579     self,
#     580     feature_group: FeatureGroup,
#    (...)
#     587     validation_id: int = None,
#     588 ):
#     589     if (
#     590         isinstance(feature_group, ExternalFeatureGroup)
#     591         and feature_group.online_enabled
#     592     ) or feature_group.stream:
# --> 593         return self._write_dataframe_kafka(
#     594             feature_group, dataframe, offline_write_options
#     595         )
#     596     else:
#     597         # for backwards compatibility
#     598         return self.legacy_save_dataframe(
#     599             feature_group,
#     600             dataframe,
#    (...)
#     606             validation_id,
#     607         )
#
# File /var/data/python/lib/python3.12/site-packages/hsfs/engine/python.py:1019, in Engine._write_dataframe_kafka(self, feature_group, dataframe, offline_write_options)
#    1010     progress_bar = tqdm(
#    1011         total=dataframe.shape[0],
#    1012         bar_format="{desc}: {percentage:.2f}% |{bar}| Rows {n_fmt}/{total_fmt} | "
#    (...)
#    1015         mininterval=1,
#    1016     )
#    1018     # set initial_check_point to the current offset
# -> 1019     initial_check_point = self._kafka_get_offsets(
#    1020         feature_group, offline_write_options, True
#    1021     )
#    1023 def acked(err, msg):
#    1024     if err is not None:
#
# File /var/data/python/lib/python3.12/site-packages/hsfs/engine/python.py:1134, in Engine._kafka_get_offsets(self, feature_group, offline_write_options, high)
#    1130 for partition_metadata in topics.get(topic_name).partitions.values():
#    1131     partition = TopicPartition(
#    1132         topic=topic_name, partition=partition_metadata.id
#    1133     )
# -> 1134     offsets += f",{partition_metadata.id}:{consumer.get_watermark_offsets(partition)[tuple_value]}"
#    1135 consumer.close()
#    1137 return f" -initialCheckPointString {topic_name + offsets}"
#
# KafkaException: KafkaError{code=_UNKNOWN_PARTITION,val=-190,str="Failed to get watermark offsets: Local: Unknown partition"}

# %% [markdown]
# ### Plot the Hindcast comparing predicted with forecasted values (1-day prior forecast)
#
# __This graph will be empty to begin with - this is normal.__
#
# After a few days of predictions and observations, you will get data points in this graph.

# %%
file_path = "../../docs/air-quality/assets/img/pm25_hindcast_1day.png"
plt = util.plot_air_quality_forecast(city, street, hindcast_df, file_path, hindcast=True)
plt.show()

# %% [markdown]
# ---
